# %% [markdown]
# Main LOO Cross Validation

# %% [markdown]
# Load Packages

# %%
from RADARDataCapture import FMCWRADARDataCapture
from MOCAPDataCapture import MOCAPDataCapture
from FPDataCapture import FPDataCapture
from StableRdmDataset import StableRdmDataset
import h5py
import os
import numpy as np
import pandas as pd
import imageio
import matplotlib.pyplot as plt
from datetime import datetime
import statistics
from matplotlib import animation
import torch
import torch.nn as nn
from torch import optim, nn
from torch.utils.data import Dataset, DataLoader, Subset
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence
from torch import optim
from datetime import datetime
from RdmSingleVariablePrediction import RdmCNNLSTMModel
from sklearn.model_selection import KFold
from scipy import stats
import random

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# Load Events Dataframe

# %%
event_csv_path = "/Users/danielcopeland/Library/Mobile Documents/com~apple~CloudDocs/MIT Masters/DRL/LABx/RADARTreePose/data/csvs/MOCAP_FP_RADAR_FU_Stable_Break_FD_TIME_FRAMES_v3.csv"

event_labels_df = pd.read_csv(event_csv_path)
print(event_labels_df.head())
# Out:
#     RADAR_capture  MOCAP_Start_Time  MOCAP_End_Time  RADAR_Start_Frame  \
# 0  01_MNTRL_RR_V1              7.33           30.57                194
# 1  01_MNTRL_RR_V1              7.33           30.57                194
# 2  01_MNTRL_RR_V1              7.33           30.57                194
# 3  01_MNTRL_RR_V2              7.37           30.40                191
# 4  01_MNTRL_RR_V2              7.37           30.40                191
#
#    RADAR_End_Frame  Seconds_per_Frame  tx  is_final_tx  t_foot_up  t_stable  \
# 0              831            0.03645   1        False      10.22     11.19
# 1              831            0.03645   2        False      18.25     19.05
# 2              831            0.03645   3         True      26.24     27.03
# 3              822            0.03646   1        False      10.48     11.05
# 4              822            0.03646   2        False      18.41     19.07
#
#    t_break  t_foot_down  frame_foot_up  frame_stable  frame_break  frame_end
# 0    14.28        15.05            273           300        384.0        405
# 1    22.18        22.83            493           515        601.0        619
# 2      NaN        30.57            712           734          NaN        831
# 3    14.27        15.05            276           292        380.0        401
# 4    22.17        22.86            493           511        596.0        615

# %% [markdown]
# Training and Testing Functions

# %%
def train_model(model, dataloader, criterion, optimizer, num_epochs=25, device=torch.device("cpu")):
    """
    Train a model on a given dataset.

    Parameters:
    - model: The neural network model to be trained.
    - dataloader: DataLoader for the training data.
    - criterion: The loss function.
    - optimizer: The optimization algorithm.
    - num_epochs: The number of epochs to train for.
    - device: The device (CPU or GPU) to train on.

    Returns:
    - model: The trained model.
    """

    # Move model to the specified device
    model.to(device)

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        model.train()  # Set model to training mode
        running_loss = 0.0

        # Iterate over data
        for inputs, velocities, _, _ in dataloader:
            inputs = inputs.to(device)
            velocities = velocities.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, velocities)

            # Backward pass + optimize
            loss.backward()
            optimizer.step()

            # Statistics
            running_loss += loss.item() * inputs.size(0)
            
        epoch_loss = running_loss / len(dataloader.dataset)
        print(f'Train Loss: {epoch_loss:.4f}\n')

    print('Training complete')
    return model


def train_validate_model(model, dataloaders, criterion, optimizer, num_epochs=25, device=torch.device("cpu")):
    
    best_val_loss = float('inf')

    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            
            # Iterate over data.
            for inputs, velocities, _, _ in dataloaders[phase]:
                inputs = inputs.to(device)
                velocities = velocities.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, velocities)

                    # Backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                
            epoch_loss = running_loss / len(dataloaders[phase].dataset)

            print(f'{phase} Loss: {epoch_loss:.4f}')

                # Track the best performance
            if phase == 'val' and epoch_loss < best_val_loss:
                best_val_loss = epoch_loss
                print(f"New best validation loss is: {best_val_loss}")
        
        print()

    print('Training complete')

    return model, best_val_loss

def test_model(model, dataloader, device=torch.device("cpu")):
    model.eval()  # Set model to evaluate mode
    running_loss = 0.0
    criterion = nn.MSELoss()  # Example criterion, adjust as necessary

    # No gradient updates
    with torch.no_grad():
        for inputs, velocities, _, _ in dataloader:
            inputs = inputs.to(device)
            velocities = velocities.to(device)

            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, velocities)

            # Statistics
            running_loss += loss.item() * inputs.size(0)

    total_loss = running_loss / len(dataloader.dataset)
    print(f'Test Loss: {total_loss:.4f}')

# %% [markdown]
# LOO Cross Validation

# %%
# Define the root directory and event CSV file path
root_dir = '/Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch'
event_csv = "/Users/danielcopeland/Library/Mobile Documents/com~apple~CloudDocs/MIT Masters/DRL/LABx/RADARTreePose/data/csvs/MOCAP_FP_RADAR_FU_Stable_Break_FD_TIME_FRAMES_v3.csv"

# Get all folders and shuffle them randomly
all_folders = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))]
random.seed(42)
random.shuffle(all_folders)

# Define the setup_loaders function
def setup_loaders(root_dir, event_csv, folders):
    datasets = {x: StableRdmDataset(root_dir, event_csv, folders[x], label_type="avg_speed") for x in ['train', 'test']}
    loaders = {x: DataLoader(datasets[x], batch_size=2, shuffle=True if x == 'train' else False, collate_fn=StableRdmDataset.collate_fn) for x in datasets}
    return loaders

# Model saving directory
model_save_dir = "/Users/danielcopeland/Library/Mobile Documents/com~apple~CloudDocs/MIT Masters/DRL/LABx/RADARTreePose/LOO_CV_models"

# Implement Leave-One-Out Cross-Validation
for i, test_folder in enumerate(all_folders):
    print(f"Starting LOO with {test_folder} as test set")
    
    # Split folders into training and test sets
    train_folders = [f for f in all_folders if f != test_folder]
    folders = {'train': train_folders, 'test': [test_folder]}
    
    # Create the DataLoaders
    loaders = setup_loaders(root_dir, event_csv, folders)
    train_loader, test_loader = loaders['train'], loaders['test']
    
    # Initialize the model
    model = RdmCNNLSTMModel(num_channels=1, hidden_dim=128, lstm_layers=2, bidirectional=False)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    # Train the model on this fold's training data
    model = train_model(model, train_loader, criterion, optimizer, num_epochs=4, device=device)
    
    # Update model save path to include the test folder name
    model_save_path = os.path.join(model_save_dir, f'model_LOO_{test_folder}.pth')
    torch.save(model.state_dict(), model_save_path)
    print(f"Model saved to {model_save_path}")

    # Evaluation logic for each test folder as needed
    # Your evaluation logic here...

print("Leave-One-Out Cross-Validation complete.")
# Out:
# Starting LOO with 13 as test set
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V1_channel1_tx1.npy
# The shape of the cpature is (32, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V1_channel2_tx1.npy
# The shape of the cpature is (32, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V1_channel3_tx1.npy
# The shape of the cpature is (32, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V1_channel4_tx1.npy
# The shape of the cpature is (32, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V1_channel1_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V1_channel2_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V1_channel3_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V1_channel4_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel1_tx1.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel2_tx1.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel3_tx1.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel4_tx1.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel1_tx2.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel2_tx2.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel3_tx2.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel4_tx2.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel1_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel2_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel3_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V2_channel4_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel1_tx1.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel2_tx1.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel3_tx1.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel4_tx1.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel1_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel2_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel3_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel4_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel1_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel2_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel3_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRL_RR_V3_channel4_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel1_tx1.npy
# The shape of the cpature is (54, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel2_tx1.npy
# The shape of the cpature is (54, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel3_tx1.npy
# The shape of the cpature is (54, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel4_tx1.npy
# The shape of the cpature is (54, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel1_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel2_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel3_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel4_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel1_tx3.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel2_tx3.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel3_tx3.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V1_channel4_tx3.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel1_tx1.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel2_tx1.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel3_tx1.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel4_tx1.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel1_tx2.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel2_tx2.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel3_tx2.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel4_tx2.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel1_tx3.npy
# The shape of the cpature is (123, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel2_tx3.npy
# The shape of the cpature is (123, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel3_tx3.npy
# The shape of the cpature is (123, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V2_channel4_tx3.npy
# The shape of the cpature is (123, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel1_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel2_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel3_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel4_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel1_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel2_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel3_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel4_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel1_tx3.npy
# The shape of the cpature is (108, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel2_tx3.npy
# The shape of the cpature is (108, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel3_tx3.npy
# The shape of the cpature is (108, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/22/22_MNTRR_RR_V3_channel4_tx3.npy
# The shape of the cpature is (108, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel1_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel2_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel3_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel4_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel1_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel2_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel3_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel4_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel1_tx3.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel2_tx3.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel3_tx3.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V2_channel4_tx3.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel1_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel2_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel3_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel4_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel1_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel2_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel3_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel4_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel1_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel2_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel3_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRL_RR_V3_channel4_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel1_tx2.npy
# The shape of the cpature is (62, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel2_tx2.npy
# The shape of the cpature is (62, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel3_tx2.npy
# The shape of the cpature is (62, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel4_tx2.npy
# The shape of the cpature is (62, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel1_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel2_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel3_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel4_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel1_tx4.npy
# The shape of the cpature is (105, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel2_tx4.npy
# The shape of the cpature is (105, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel3_tx4.npy
# The shape of the cpature is (105, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V1_channel4_tx4.npy
# The shape of the cpature is (105, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel1_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel2_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel3_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel4_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel1_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel2_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel3_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel4_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel1_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel2_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel3_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V2_channel4_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel1_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel2_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel3_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel4_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel1_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel2_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel3_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel4_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel1_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel2_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel3_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/12/12_MNTRR_RR_V3_channel4_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel1_tx1.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel2_tx1.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel3_tx1.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel4_tx1.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel1_tx2.npy
# The shape of the cpature is (83, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel2_tx2.npy
# The shape of the cpature is (83, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel3_tx2.npy
# The shape of the cpature is (83, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel4_tx2.npy
# The shape of the cpature is (83, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel1_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel2_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel3_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V1_channel4_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel1_tx1.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel2_tx1.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel3_tx1.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel4_tx1.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel1_tx2.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel2_tx2.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel3_tx2.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel4_tx2.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel1_tx3.npy
# The shape of the cpature is (65, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel2_tx3.npy
# The shape of the cpature is (65, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel3_tx3.npy
# The shape of the cpature is (65, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V2_channel4_tx3.npy
# The shape of the cpature is (65, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel1_tx1.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel2_tx1.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel3_tx1.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel4_tx1.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel1_tx2.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel2_tx2.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel3_tx2.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel4_tx2.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel1_tx3.npy
# The shape of the cpature is (88, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel2_tx3.npy
# The shape of the cpature is (88, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel3_tx3.npy
# The shape of the cpature is (88, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRL_RR_V3_channel4_tx3.npy
# The shape of the cpature is (88, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel1_tx1.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel2_tx1.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel3_tx1.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel4_tx1.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel1_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel2_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel3_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel4_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel1_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel2_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel3_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V1_channel4_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel1_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel2_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel3_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel4_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel1_tx2.npy
# The shape of the cpature is (88, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel2_tx2.npy
# The shape of the cpature is (88, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel3_tx2.npy
# The shape of the cpature is (88, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel4_tx2.npy
# The shape of the cpature is (88, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel1_tx3.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel2_tx3.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel3_tx3.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V2_channel4_tx3.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel1_tx1.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel2_tx1.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel3_tx1.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel4_tx1.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel1_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel2_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel3_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel4_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel1_tx3.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel2_tx3.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel3_tx3.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/10/10_MNTRR_RR_V3_channel4_tx3.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel1_tx1.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel2_tx1.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel3_tx1.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel4_tx1.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel1_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel2_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel3_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel4_tx2.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel1_tx3.npy
# The shape of the cpature is (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel2_tx3.npy
# The shape of the cpature is (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel3_tx3.npy
# The shape of the cpature is (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel4_tx3.npy
# The shape of the cpature is (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel1_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel2_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel3_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel4_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel1_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel2_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel3_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel4_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel1_tx3.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel2_tx3.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel3_tx3.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel4_tx3.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel1_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel2_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel3_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel4_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel1_tx2.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel2_tx2.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel3_tx2.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel4_tx2.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel1_tx3.npy
# The shape of the cpature is (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel2_tx3.npy
# The shape of the cpature is (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel3_tx3.npy
# The shape of the cpature is (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel4_tx3.npy
# The shape of the cpature is (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel1_tx1.npy
# The shape of the cpature is (45, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel2_tx1.npy
# The shape of the cpature is (45, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel3_tx1.npy
# The shape of the cpature is (45, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel4_tx1.npy
# The shape of the cpature is (45, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel1_tx3.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel2_tx3.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel3_tx3.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel4_tx3.npy
# The shape of the cpature is (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel1_tx4.npy
# The shape of the cpature is (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel2_tx4.npy
# The shape of the cpature is (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel3_tx4.npy
# The shape of the cpature is (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel4_tx4.npy
# The shape of the cpature is (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel1_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel2_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel3_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel4_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel1_tx2.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel2_tx2.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel3_tx2.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel4_tx2.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel1_tx3.npy
# The shape of the cpature is (104, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel2_tx3.npy
# The shape of the cpature is (104, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel3_tx3.npy
# The shape of the cpature is (104, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel4_tx3.npy
# The shape of the cpature is (104, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel1_tx1.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel2_tx1.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel3_tx1.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel4_tx1.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel1_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel2_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel3_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel4_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel1_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel2_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel3_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel4_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel1_tx1.npy
# The shape of the cpature is (86, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel2_tx1.npy
# The shape of the cpature is (86, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel3_tx1.npy
# The shape of the cpature is (86, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel4_tx1.npy
# The shape of the cpature is (86, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel1_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel2_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel3_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel4_tx2.npy
# The shape of the cpature is (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel1_tx3.npy
# The shape of the cpature is (110, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel2_tx3.npy
# The shape of the cpature is (110, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel3_tx3.npy
# The shape of the cpature is (110, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V1_channel4_tx3.npy
# The shape of the cpature is (110, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel1_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel2_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel3_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel4_tx1.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel1_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel2_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel3_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel4_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel1_tx3.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel2_tx3.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel3_tx3.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V2_channel4_tx3.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel1_tx1.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel2_tx1.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel3_tx1.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel4_tx1.npy
# The shape of the cpature is (84, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel1_tx2.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel2_tx2.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel3_tx2.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel4_tx2.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel1_tx3.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel2_tx3.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel3_tx3.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRL_RR_V3_channel4_tx3.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel1_tx1.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel2_tx1.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel3_tx1.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel4_tx1.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel1_tx2.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel2_tx2.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel3_tx2.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel4_tx2.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel1_tx3.npy
# The shape of the cpature is (73, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel2_tx3.npy
# The shape of the cpature is (73, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel3_tx3.npy
# The shape of the cpature is (73, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V1_channel4_tx3.npy
# The shape of the cpature is (73, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel1_tx1.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel2_tx1.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel3_tx1.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel4_tx1.npy
# The shape of the cpature is (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel1_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel2_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel3_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel4_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel1_tx3.npy
# The shape of the cpature is (107, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel2_tx3.npy
# The shape of the cpature is (107, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel3_tx3.npy
# The shape of the cpature is (107, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V2_channel4_tx3.npy
# The shape of the cpature is (107, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V3_channel1_tx1.npy
# The shape of the cpature is (81, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V3_channel2_tx1.npy
# The shape of the cpature is (81, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/18/18_MNTRR_RR_V3_channel3_tx1.npy
# ...
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRL_RR_V3_channel4_tx3.npy
# The shape of the cpature is (72, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel1_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel2_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel3_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel4_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel1_tx2.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel2_tx2.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel3_tx2.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel4_tx2.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel1_tx3.npy
# The shape of the cpature is (80, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel2_tx3.npy
# The shape of the cpature is (80, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel3_tx3.npy
# The shape of the cpature is (80, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V1_channel4_tx3.npy
# The shape of the cpature is (80, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel1_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel2_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel3_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel4_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel1_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel2_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel3_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel4_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel1_tx3.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel2_tx3.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel3_tx3.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V2_channel4_tx3.npy
# The shape of the cpature is (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel1_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel2_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel3_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel4_tx1.npy
# The shape of the cpature is (82, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel1_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel2_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel3_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel4_tx2.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel1_tx3.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel2_tx3.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel3_tx3.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/02/02_MNTRR_RR_V3_channel4_tx3.npy
# The shape of the cpature is (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel1_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel2_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel3_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel4_tx1.npy
# The shape of the cpature is (95, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel1_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel2_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel3_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel4_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel1_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel2_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel3_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V1_channel4_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel1_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel2_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel3_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel4_tx1.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel1_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel2_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel3_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel4_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel1_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel2_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel3_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V2_channel4_tx3.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel1_tx1.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel2_tx1.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel3_tx1.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel4_tx1.npy
# The shape of the cpature is (90, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel1_tx2.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel2_tx2.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel3_tx2.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel4_tx2.npy
# The shape of the cpature is (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel1_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel2_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel3_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRL_RR_V3_channel4_tx3.npy
# The shape of the cpature is (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel1_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel2_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel3_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel4_tx1.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel1_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel2_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel3_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel4_tx2.npy
# The shape of the cpature is (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel1_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel2_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel3_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V1_channel4_tx3.npy
# The shape of the cpature is (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel1_tx1.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel2_tx1.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel3_tx1.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel4_tx1.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel1_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel2_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel3_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel4_tx2.npy
# The shape of the cpature is (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel1_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel2_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel3_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V2_channel4_tx3.npy
# The shape of the cpature is (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel1_tx1.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel2_tx1.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel3_tx1.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel4_tx1.npy
# The shape of the cpature is (94, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel1_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel2_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel3_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel4_tx2.npy
# The shape of the cpature is (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel1_tx3.npy
# The shape of the cpature is (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel2_tx3.npy
# The shape of the cpature is (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel3_tx3.npy
# The shape of the cpature is (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/15/15_MNTRR_RR_V3_channel4_tx3.npy
# The shape of the cpature is (98, 23, 13)
# Epoch 1/4
# ----------
# Train Loss: 0.0035
#
# Epoch 2/4
# ----------
# Train Loss: 0.0025
#
# Epoch 3/4
# ----------
# Train Loss: 0.0023
#
# Epoch 4/4
# ----------
# Train Loss: 0.0023
#
# Training complete
# Model saved to /Users/danielcopeland/Library/Mobile Documents/com~apple~CloudDocs/MIT Masters/DRL/LABx/RADARTreePose/LOO_CV_models/model_LOO_15.pth
# Leave-One-Out Cross-Validation complete.

# %% [markdown]
# Fine Tune Models

# %%
from torch.utils.data import DataLoader, Subset, random_split
from sklearn.model_selection import train_test_split


# Define the setup_loaders function
def setup_test_loaders(root_dir, event_csv, folders):
    datasets = {x: StableRdmDataset(root_dir, event_csv, folders[x], label_type="avg_speed") for x in ['test']}
    loaders = {x: DataLoader(datasets[x], batch_size=2, shuffle=True if x == 'train' else False, collate_fn=StableRdmDataset.collate_fn) for x in datasets}
    return loaders


def load_model(model_path, device):
    """Load a pre-trained model."""
    model = RdmCNNLSTMModel(num_channels=1, hidden_dim=128, lstm_layers=2, bidirectional=False) # Instantiate your model class
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.to(device)
    return model

def prepare_data_for_participant(test_loader, fraction=0.2, seed=42):
    """
    Splits the test participant's data into fine-tuning and evaluation subsets.
    
    Parameters:
    - test_loader: DataLoader for the test participant's data.
    - fraction: Fraction of data to use for fine-tuning.
    - seed: Random seed for reproducibility.
    
    Returns:
    - fine_tune_loader: DataLoader for the fine-tuning subset.
    - eval_loader: DataLoader for the evaluation subset.
    """
    # Determine split sizes
    total_size = len(test_loader.dataset)
    fine_tune_size = int(fraction * total_size)
    eval_size = total_size - fine_tune_size
    
    # Split the dataset
    fine_tune_subset, eval_subset = random_split(
        test_loader.dataset,
        [fine_tune_size, eval_size],
        generator=torch.Generator().manual_seed(seed)
    )
    
    # Create DataLoaders for each subset
    fine_tune_loader = DataLoader(fine_tune_subset, batch_size=2, shuffle=True, collate_fn=StableRdmDataset.collate_fn)
    eval_loader = DataLoader(eval_subset, batch_size=2, shuffle=False, collate_fn=StableRdmDataset.collate_fn)

    return fine_tune_loader, eval_loader

def fine_tune_model(model, fine_tune_loader, device, epochs=3):
    """Fine-tunes the model on a subset of data."""
    model.train()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()  # Or your specific loss function
    for epoch in range(epochs):
        for inputs, labels, length, metadata in fine_tune_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

def evaluate_model(model, test_loader, device):
    model.eval()
    predictions, actuals = [], []
    with torch.no_grad():
        for batch in test_loader:
            # Assuming the first two elements are inputs and labels
            inputs, labels = batch[0].to(device), batch[1].to(device)
            
            # In case your model expects inputs in a specific shape based on 'length'
            # Adjust 'inputs' here if necessary, e.g., using 'length' to pack sequences
            
            outputs = model(inputs)
            predictions.extend(outputs.view(-1).cpu().numpy())
            actuals.extend(labels.view(-1).cpu().numpy())


    # Calculate R^2 score
    r2 = r2_score(actuals, predictions)
    return r2

def main():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    models_dir = "/Users/danielcopeland/Library/Mobile Documents/com~apple~CloudDocs/MIT Masters/DRL/LABx/RADARTreePose/LOO_CV_models"
    root_dir = '/Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch'
    event_csv = "/Users/danielcopeland/Library/Mobile Documents/com~apple~CloudDocs/MIT Masters/DRL/LABx/RADARTreePose/data/csvs/MOCAP_FP_RADAR_FU_Stable_Break_FD_TIME_FRAMES_v3.csv"
    
    # Automatically load model paths
    model_paths = [os.path.join(models_dir, f) for f in os.listdir(models_dir) if f.startswith('model_LOO_') and f.endswith('.pth')]
    
    # Get all folders and shuffle them randomly for reproducibility if needed
    all_folders = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))]
    random.seed(42)
    random.shuffle(all_folders)

    for model_path in model_paths:
        model_name = os.path.basename(model_path)
        test_folder = model_name.replace('model_LOO_', '').replace('.pth', '')
        print(f"Evaluating {model_name} with {test_folder} as the test set")

        # Ensure the test folder is one of the available folders, skip otherwise
        if test_folder not in all_folders:
            print(f"Test folder {test_folder} not found in the dataset. Skipping...")
            continue

        model = load_model(model_path, device)
        folders = {'test': [test_folder]}
        loaders = setup_test_loaders(root_dir, event_csv, folders)
        test_loader = loaders['test']

        model_r2_scores = []

        for fraction in np.linspace(0.1, 0.5, 5):  # Incremental portions of the test data for fine-tuning
            # Use the prepare_data_for_participant function to split the dataset
            fine_tune_loader, eval_loader = prepare_data_for_participant(test_loader, fraction=fraction, seed=42)
            
            # Fine-tune the model with the fine_tune_loader
            fine_tune_model(model, fine_tune_loader, device)
            
            # Evaluate the model with the eval_loader (contains data not seen during fine-tuning)
            r2 = evaluate_model(model, eval_loader, device)
            model_r2_scores.append((fraction, r2))

        r2_scores.append((test_folder, model_r2_scores))

    # Plotting logic remains the same

if __name__ == "__main__":
    main()
# Out:
# Evaluating model_LOO_24.pth with 24 as the test set
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel1_tx1.npy
# The shape of the 24_MNTRL_RR_V1 is: (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel2_tx1.npy
# The shape of the 24_MNTRL_RR_V1 is: (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel3_tx1.npy
# The shape of the 24_MNTRL_RR_V1 is: (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel4_tx1.npy
# The shape of the 24_MNTRL_RR_V1 is: (100, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel1_tx2.npy
# The shape of the 24_MNTRL_RR_V1 is: (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel2_tx2.npy
# The shape of the 24_MNTRL_RR_V1 is: (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel3_tx2.npy
# The shape of the 24_MNTRL_RR_V1 is: (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel4_tx2.npy
# The shape of the 24_MNTRL_RR_V1 is: (101, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel1_tx3.npy
# The shape of the 24_MNTRL_RR_V1 is: (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel2_tx3.npy
# The shape of the 24_MNTRL_RR_V1 is: (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel3_tx3.npy
# The shape of the 24_MNTRL_RR_V1 is: (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V1_channel4_tx3.npy
# The shape of the 24_MNTRL_RR_V1 is: (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel1_tx1.npy
# The shape of the 24_MNTRL_RR_V2 is: (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel2_tx1.npy
# The shape of the 24_MNTRL_RR_V2 is: (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel3_tx1.npy
# The shape of the 24_MNTRL_RR_V2 is: (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel4_tx1.npy
# The shape of the 24_MNTRL_RR_V2 is: (96, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel1_tx2.npy
# The shape of the 24_MNTRL_RR_V2 is: (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel2_tx2.npy
# The shape of the 24_MNTRL_RR_V2 is: (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel3_tx2.npy
# The shape of the 24_MNTRL_RR_V2 is: (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel4_tx2.npy
# The shape of the 24_MNTRL_RR_V2 is: (92, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel1_tx3.npy
# The shape of the 24_MNTRL_RR_V2 is: (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel2_tx3.npy
# The shape of the 24_MNTRL_RR_V2 is: (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel3_tx3.npy
# The shape of the 24_MNTRL_RR_V2 is: (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V2_channel4_tx3.npy
# The shape of the 24_MNTRL_RR_V2 is: (87, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel1_tx1.npy
# The shape of the 24_MNTRL_RR_V3 is: (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel2_tx1.npy
# The shape of the 24_MNTRL_RR_V3 is: (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel3_tx1.npy
# The shape of the 24_MNTRL_RR_V3 is: (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel4_tx1.npy
# The shape of the 24_MNTRL_RR_V3 is: (93, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel1_tx2.npy
# The shape of the 24_MNTRL_RR_V3 is: (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel2_tx2.npy
# The shape of the 24_MNTRL_RR_V3 is: (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel3_tx2.npy
# The shape of the 24_MNTRL_RR_V3 is: (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel4_tx2.npy
# The shape of the 24_MNTRL_RR_V3 is: (85, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel1_tx3.npy
# The shape of the 24_MNTRL_RR_V3 is: (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel2_tx3.npy
# The shape of the 24_MNTRL_RR_V3 is: (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel3_tx3.npy
# The shape of the 24_MNTRL_RR_V3 is: (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRL_RR_V3_channel4_tx3.npy
# The shape of the 24_MNTRL_RR_V3 is: (98, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel1_tx1.npy
# The shape of the 24_MNTRR_RR_V1 is: (45, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel2_tx1.npy
# The shape of the 24_MNTRR_RR_V1 is: (45, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel3_tx1.npy
# The shape of the 24_MNTRR_RR_V1 is: (45, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel4_tx1.npy
# The shape of the 24_MNTRR_RR_V1 is: (45, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel1_tx3.npy
# The shape of the 24_MNTRR_RR_V1 is: (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel2_tx3.npy
# The shape of the 24_MNTRR_RR_V1 is: (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel3_tx3.npy
# The shape of the 24_MNTRR_RR_V1 is: (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel4_tx3.npy
# The shape of the 24_MNTRR_RR_V1 is: (103, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel1_tx4.npy
# The shape of the 24_MNTRR_RR_V1 is: (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel2_tx4.npy
# The shape of the 24_MNTRR_RR_V1 is: (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel3_tx4.npy
# The shape of the 24_MNTRR_RR_V1 is: (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V1_channel4_tx4.npy
# The shape of the 24_MNTRR_RR_V1 is: (109, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel1_tx1.npy
# The shape of the 24_MNTRR_RR_V2 is: (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel2_tx1.npy
# The shape of the 24_MNTRR_RR_V2 is: (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel3_tx1.npy
# The shape of the 24_MNTRR_RR_V2 is: (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel4_tx1.npy
# The shape of the 24_MNTRR_RR_V2 is: (89, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel1_tx2.npy
# The shape of the 24_MNTRR_RR_V2 is: (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel2_tx2.npy
# The shape of the 24_MNTRR_RR_V2 is: (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel3_tx2.npy
# The shape of the 24_MNTRR_RR_V2 is: (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel4_tx2.npy
# The shape of the 24_MNTRR_RR_V2 is: (91, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel1_tx3.npy
# The shape of the 24_MNTRR_RR_V2 is: (104, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel2_tx3.npy
# The shape of the 24_MNTRR_RR_V2 is: (104, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel3_tx3.npy
# The shape of the 24_MNTRR_RR_V2 is: (104, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V2_channel4_tx3.npy
# The shape of the 24_MNTRR_RR_V2 is: (104, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel1_tx1.npy
# The shape of the 24_MNTRR_RR_V3 is: (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel2_tx1.npy
# The shape of the 24_MNTRR_RR_V3 is: (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel3_tx1.npy
# The shape of the 24_MNTRR_RR_V3 is: (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel4_tx1.npy
# The shape of the 24_MNTRR_RR_V3 is: (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel1_tx2.npy
# The shape of the 24_MNTRR_RR_V3 is: (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel2_tx2.npy
# The shape of the 24_MNTRR_RR_V3 is: (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel3_tx2.npy
# The shape of the 24_MNTRR_RR_V3 is: (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel4_tx2.npy
# The shape of the 24_MNTRR_RR_V3 is: (97, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel1_tx3.npy
# The shape of the 24_MNTRR_RR_V3 is: (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel2_tx3.npy
# The shape of the 24_MNTRR_RR_V3 is: (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel3_tx3.npy
# The shape of the 24_MNTRR_RR_V3 is: (99, 23, 13)
# found capture tx: /Volumes/FourTBLaCie/Yoga_Study_RADAR_Stable_1Ch/24/24_MNTRR_RR_V3_channel4_tx3.npy
# The shape of the 24_MNTRR_RR_V3 is: (99, 23, 13)
# /Users/danielcopeland/opt/anaconda3/envs/radartreepose_env/lib/python3.10/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/danielcopeland/opt/anaconda3/envs/radartreepose_env/lib/python3.10/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/danielcopeland/opt/anaconda3/envs/radartreepose_env/lib/python3.10/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Users/danielcopeland/opt/anaconda3/envs/radartreepose_env/lib/python3.10/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 131
#     128     # Plotting logic remains the same
#     130 if __name__ == "__main__":
# --> 131     main()
#
# Cell In[10], line 123, in main()
#     120     fine_tune_model(model, fine_tune_loader, device)
#     122     # Evaluate the model with the eval_loader (contains data not seen during fine-tuning)
# --> 123     r2 = evaluate_model(model, eval_loader, device)
#     124     model_r2_scores.append((fraction, r2))
#     126 r2_scores.append((test_folder, model_r2_scores))
#
# Cell In[10], line 81, in evaluate_model(model, test_loader, device)
#      77         actuals.extend(labels.view(-1).cpu().numpy())
#      80 # Calculate R^2 score
# ---> 81 r2 = r2_score(actuals, predictions)
#      82 return r2
#
# File ~/opt/anaconda3/envs/radartreepose_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/opt/anaconda3/envs/radartreepose_env/lib/python3.10/site-packages/sklearn/metrics/_regression.py:1180, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#    1039 @validate_params(
#    1040     {
#    1041         "y_true": ["array-like"],
#    (...)
#    1059     force_finite=True,
#    1060 ):
#    1061     """:math:`R^2` (coefficient of determination) regression score function.
#    1062
#    1063     Best possible score is 1.0 and it can be negative (because the
#    (...)
#    1178     -inf
#    1179     """
# -> 1180     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#    1181         y_true, y_pred, multioutput
#    1182     )
#    1183     check_consistent_length(y_true, y_pred, sample_weight)
#    1185     if _num_samples(y_pred) < 2:
#
# File ~/opt/anaconda3/envs/radartreepose_env/lib/python3.10/site-packages/sklearn/metrics/_regression.py:103, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      69 """Check that y_true and y_pred belong to the same regression task.
#      70
#      71 Parameters
#    (...)
#     100     correct keyword.
#     101 """
#     102 check_consistent_length(y_true, y_pred)
# --> 103 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     104 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     106 if y_true.ndim == 1:
#
# File ~/opt/anaconda3/envs/radartreepose_env/lib/python3.10/site-packages/sklearn/utils/validation.py:1072, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1070     n_samples = _num_samples(array)
#    1071     if n_samples < ensure_min_samples:
# -> 1072         raise ValueError(
#    1073             "Found array with %d sample(s) (shape=%s) while a"
#    1074             " minimum of %d is required%s."
#    1075             % (n_samples, array.shape, ensure_min_samples, context)
#    1076         )
#    1078 if ensure_min_features > 0 and array.ndim == 2:
#    1079     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %% [markdown]
# Plot R2 vs % data included

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example r2_scores structure for clarity:
# r2_scores = [
#     ('model_LOO_folder1', [(0.1, 0.8), (0.2, 0.82), ..., (1.0, 0.9)]),
#     ('model_LOO_folder2', [(0.1, 0.75), (0.2, 0.77), ..., (1.0, 0.88)]),
#     ...
# ]

# Assuming r2_scores is filled as above
# Generate a unique color for each test folder
colors = plt.cm.jet(np.linspace(0, 1, len(r2_scores)))

plt.figure(figsize=(10, 7))

for (model_name, scores), color in zip(r2_scores, colors):
    # Extract the fraction of test data and corresponding R^2 scores
    fractions, r2s = zip(*scores)
    test_folder = model_name.replace('model_LOO_', '')
    plt.plot(fractions, r2s, label=f'{test_folder}', color=color)

plt.xlabel('% of Test Data Used for Fine-Tuning')
plt.ylabel('R^2 Score')
plt.title('Model Performance vs. % Fine-Tuning by Test Folder')
plt.legend(title='Test Folder', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
